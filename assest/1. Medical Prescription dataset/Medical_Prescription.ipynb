# %%
# %pip install datasets pandas pillow
# Out:
# Requirement already satisfied: datasets in c:\users\hp\anaconda3\lib\site-packages (4.8.4)
# Requirement already satisfied: pandas in c:\users\hp\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: pillow in c:\users\hp\anaconda3\lib\site-packages (11.1.0)
# Requirement already satisfied: filelock in c:\users\hp\anaconda3\lib\site-packages (from datasets) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\hp\anaconda3\lib\site-packages (from datasets) (2.1.3)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\hp\anaconda3\lib\site-packages (from datasets) (23.0.1)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in c:\users\hp\anaconda3\lib\site-packages (from datasets) (0.4.1)
# Requirement already satisfied: requests>=2.32.2 in c:\users\hp\anaconda3\lib\site-packages (from datasets) (2.32.3)
# Requirement already satisfied: httpx<1.0.0 in c:\users\hp\anaconda3\lib\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\hp\anaconda3\lib\site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in c:\users\hp\anaconda3\lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in c:\users\hp\anaconda3\lib\site-packages (from datasets) (0.70.19)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in c:\users\hp\anaconda3\lib\site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2025.3.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in c:\users\hp\anaconda3\lib\site-packages (from datasets) (1.8.0)
# Requirement already satisfied: packaging in c:\users\hp\anaconda3\lib\site-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\hp\anaconda3\lib\site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\hp\anaconda3\lib\site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.11.10)
# Requirement already satisfied: anyio in c:\users\hp\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (4.7.0)
# Requirement already satisfied: certifi in c:\users\hp\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\hp\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in c:\users\hp\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\hp\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in c:\users\hp\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.4.2)
# Requirement already satisfied: typer in c:\users\hp\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\hp\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\hp\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\hp\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\hp\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\hp\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\hp\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\hp\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\hp\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.18.0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hp\anaconda3\lib\site-packages (from anyio->httpx<1.0.0->datasets) (1.3.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\hp\anaconda3\lib\site-packages (from typer->huggingface-hub<2.0,>=0.25.0->datasets) (8.1.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

# %%
import os
from PIL import Image
import matplotlib.pyplot as plt

DATASET_PATH = "Medical-Prescription-Dataset/images"

images = os.listdir(DATASET_PATH)

print("Total Images:", len(images))

# show one image
img = Image.open(os.path.join(DATASET_PATH, images[0]))
plt.imshow(img)
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 7
#       3 import matplotlib.pyplot as plt
#       5 DATASET_PATH = "Medical-Prescription-Dataset/images"
# ----> 7 images = os.listdir(DATASET_PATH)
#       9 print("Total Images:", len(images))
#      11 # show one image
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'Medical-Prescription-Dataset/images'

# %%
from datasets import load_dataset
dataset  = load_dataset("Medical-Prescription-Dataset/images")
print(dataset)
# Out:
# ---------------------------------------------------------------------------
# DatasetNotFoundError                      Traceback (most recent call last)
# Cell In[15], line 2
#       1 from datasets import load_dataset
# ----> 2 dataset  = load_dataset("Medical-Prescription-Dataset/images")
#       3 print(dataset)
#
# File ~\anaconda3\Lib\site-packages\datasets\load.py:1688, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1683 verification_mode = VerificationMode(
#    1684     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    1685 )
#    1687 # Create a dataset builder
# -> 1688 builder_instance = load_dataset_builder(
#    1689     path=path,
#    1690     name=name,
#    1691     data_dir=data_dir,
#    1692     data_files=data_files,
#    1693     cache_dir=cache_dir,
#    1694     features=features,
#    1695     download_config=download_config,
#    1696     download_mode=download_mode,
#    1697     revision=revision,
#    1698     token=token,
#    1699     storage_options=storage_options,
#    1700     **config_kwargs,
#    1701 )
#    1703 # Return iterable dataset in case of streaming
#    1704 if streaming:
#
# File ~\anaconda3\Lib\site-packages\datasets\load.py:1315, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, **config_kwargs)
#    1313 if features is not None:
#    1314     features = _fix_for_backward_compatible_features(features)
# -> 1315 dataset_module = dataset_module_factory(
#    1316     path,
#    1317     revision=revision,
#    1318     download_config=download_config,
#    1319     download_mode=download_mode,
#    1320     data_dir=data_dir,
#    1321     data_files=data_files,
#    1322     cache_dir=cache_dir,
#    1323 )
#    1324 # Get dataset builder class
#    1325 builder_kwargs = dataset_module.builder_kwargs
#
# File ~\anaconda3\Lib\site-packages\datasets\load.py:1201, in dataset_module_factory(path, revision, download_config, download_mode, data_dir, data_files, cache_dir, **download_kwargs)
#    1199     raise ConnectionError(f"Couldn't reach the Hugging Face Hub for dataset '{path}': {e1}") from None
#    1200 if isinstance(e1, (DataFilesNotFoundError, DatasetNotFoundError, EmptyDatasetError)):
# -> 1201     raise e1 from None
#    1202 if isinstance(e1, FileNotFoundError):
#    1203     raise FileNotFoundError(
#    1204         f"Couldn't find any data file at {relative_to_absolute_path(path)}. "
#    1205         f"Couldn't find '{path}' on the Hugging Face Hub either: {type(e1).__name__}: {e1}"
#    1206     ) from None
#
# File ~\anaconda3\Lib\site-packages\datasets\load.py:1158, in dataset_module_factory(path, revision, download_config, download_mode, data_dir, data_files, cache_dir, **download_kwargs)
#    1156     raise DatasetNotFoundError(message) from e
#    1157 except RepositoryNotFoundError as e:
# -> 1158     raise DatasetNotFoundError(f"Dataset '{path}' doesn't exist on the Hub or cannot be accessed.") from e
#    1159 try:
#    1160     api.hf_hub_download(
#    1161         repo_id=path,
#    1162         filename=filename,
#    (...)
#    1165         proxies=download_config.proxies,
#    1166     )
#
# DatasetNotFoundError: Dataset 'Medical-Prescription-Dataset/images' doesn't exist on the Hub or cannot be accessed.
