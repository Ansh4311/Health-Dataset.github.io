# %%
# Install required libraries
import sys
# !{sys.executable} -m pip install kagglehub pandas
# Out:
# Collecting kagglehub
#   Downloading kagglehub-1.0.0-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: pandas in c:\users\hp\anaconda3\lib\site-packages (2.2.3)
# Collecting kagglesdk<1.0,>=0.1.14 (from kagglehub)
#   Downloading kagglesdk-0.1.17-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in c:\users\hp\anaconda3\lib\site-packages (from kagglehub) (24.2)
# Requirement already satisfied: pyyaml in c:\users\hp\anaconda3\lib\site-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in c:\users\hp\anaconda3\lib\site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\hp\anaconda3\lib\site-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: protobuf in c:\users\hp\anaconda3\lib\site-packages (from kagglesdk<1.0,>=0.1.14->kagglehub) (5.29.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests->kagglehub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests->kagglehub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests->kagglehub) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests->kagglehub) (2026.1.4)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Downloading kagglehub-1.0.0-py3-none-any.whl (70 kB)
# Downloading kagglesdk-0.1.17-py3-none-any.whl (201 kB)
# Installing collected packages: kagglesdk, kagglehub
#
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    -------------------- ------------------- 1/2 [kagglehub]
#    -------------------- ------------------- 1/2 [kagglehub]
#    -------------------- ------------------- 1/2 [kagglehub]
#    ---------------------------------------- 2/2 [kagglehub]
#
# Successfully installed kagglehub-1.0.0 kagglesdk-0.1.17

# %%
import pandas as pd
import os
import json
import kagglehub

# Create output folder
output_folder = "medical_prescription_dataset"
os.makedirs(output_folder, exist_ok=True)

# Download dataset
path = kagglehub.dataset_download("nadaarfaoui/ocr-processed-handwritten-prescriptions")

print("Dataset downloaded at:", path)
# Out:
# Downloading to C:\Users\HP\.cache\kagglehub\datasets\nadaarfaoui\ocr-processed-handwritten-prescriptions\4.archive...
# 100%|██████████| 15.8M/15.8M [00:04<00:00, 3.75MB/s]
# Extracting files...
# Dataset downloaded at: C:\Users\HP\.cache\kagglehub\datasets\nadaarfaoui\ocr-processed-handwritten-prescriptions\versions\4

# %%
# Check files inside dataset folder
import os

files = os.listdir(path)
print(files)
# Out:
# ['data', '__huggingface_repos__.json']

# %%
import os
import pandas as pd

data_folder = os.path.join(path, "data")

print(os.listdir(data_folder))
# Out:
# ['processed']

# %%
import os
import pandas as pd

csv_file = None

for root, dirs, files in os.walk(path):
    for file in files:
        if file.endswith(".csv"):
            csv_file = os.path.join(root, file)
            break

print("CSV file found:", csv_file)

df = pd.read_csv(csv_file)

df.head()
# Out:
# CSV file found: C:\Users\HP\.cache\kagglehub\datasets\nadaarfaoui\ocr-processed-handwritten-prescriptions\versions\4\data\processed\test_labels.csv
#    IMAGE  MEDICINE_NAME
# 0  0.png              0
# 1  1.png              0
# 2  2.png              0
# 3  3.png              0
# 4  4.png              0

# %%
df_1000 = df.head(1000)

df_1000.to_csv("prescription_1000.csv", index=False)
df_1000.to_json("prescription_1000.json", orient="records", indent=4)

print("Saved successfully")
# Out:
# Saved successfully

# %%
# Save as CSV
csv_output = os.path.join(output_folder, "prescription_1000.csv")
df_1000.to_csv(csv_output, index=False)

print("CSV saved at:", csv_output)
# Out:
# CSV saved at: medical_prescription_dataset\prescription_1000.csv
