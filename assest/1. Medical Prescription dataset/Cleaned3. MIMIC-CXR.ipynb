# %%
# !pip install -q kagglehub
import numpy as np
import os
import cv2
import shutil
import pandas as pd
import kagglehub

# Download dataset
dataset_path = kagglehub.dataset_download(
    "paultimothymooney/chest-xray-pneumonia"
)

# Output folder
output_folder = "Chest_Xray"

os.makedirs(output_folder, exist_ok=True)

image_paths = []
labels = []

count = 0

# Process images
for root, dirs, files in os.walk(dataset_path):

    for file in files:

        if file.lower().endswith((".jpeg", ".jpg", ".png")):

            path = os.path.join(root, file)

            img = cv2.imread(
                path,
                cv2.IMREAD_GRAYSCALE
            )

            if img is None:
                continue

            # Resize
            img = cv2.resize(img, (256, 256))

            # Save image
            save_path = os.path.join(
                output_folder,
                f"xray_{count}.png"
            )

            cv2.imwrite(save_path, img)

            # Label
            if "PNEUMONIA" in root.upper():
                label = "PNEUMONIA"
            else:
                label = "NORMAL"

            image_paths.append(save_path)
            labels.append(label)

            count += 1

print("Images:", len(image_paths))

# CSV
df = pd.DataFrame({
    "image_path": image_paths,
    "label": labels
})

df.to_csv("xray_labels.csv", index=False)

print("Done")
# Out:
# Access is denied.
# Downloading to C:\Users\HP\.cache\kagglehub\datasets\paultimothymooney\chest-xray-pneumonia\2.archive...
# 100%|██████████| 2.29G/2.29G [03:37<00:00, 11.3MB/s]
# Extracting files...
# Images: 11712
# Done
